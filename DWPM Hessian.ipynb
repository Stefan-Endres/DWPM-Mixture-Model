# %%
from __future__ import division
from sympy import symbols, Function, diff, solve, init_printing, latex, cos, acos, ln, sqrt, Rational, pi, Abs
init_printing(use_unicode=True)
f, g = symbols('f g', cls=Function)

# %% [markdown]
# # Define Variables and Functionals

# %%
P, T, R, V_i_k, V_z_k, V_j_k, V_z, a_im, r, s, Sigma_n_i = symbols('P, T, R, V_i^k, V_z^k, V_j^k V_z a_im, r, s, Sigma^n_i=1')
a_j, a_z, a_i, b_j, b_z, b_i, x_i, x_j, x_z = symbols('a_j, a_z, a_i, b_j, b_z, b_i, x_i, x_j, x_z')
f, g_i_R_k, g_mix_R_k, a_mix, b_mix, V_mix_k = symbols('f, g_i^R\,k, g_mix^R\,k, a_mix, b_mix, V_mix^k', cls=Function)

# %%
x_j_func = 1 - x_z - Sigma_n_i * x_i # Eliminate non-independent variable
x_j_func
# Out:
# -Σⁿᵢ₌₁⋅xᵢ - x_z + 1

# %%
V_z_k
# Out:
# V_z__k

# %%
g_mix_R_k(x_z)
# Out:
# g_mix__R,k(x_z)

# %%
diff(a_mix(x_z), x_z)
# Out:
#  d
# ────(aₘᵢₓ(x_z))
# dx_z

# %%
ln(x_z)
# Out:
# log(x_z)

# %% [markdown]
# # Gibbs Energy

# %% [markdown]
# ## Ideal gas terms

# %%
idg_func = x_z * ln(x_z) + x_j * ln(x_j) + Sigma_n_i * x_i * ln(x_i)
idg_func = idg_func.subs(x_j, x_j_func )
idg_func
# Out:
# Σⁿᵢ₌₁⋅xᵢ⋅log(xᵢ) + x_z⋅log(x_z) + (-Σⁿᵢ₌₁⋅xᵢ - x_z + 1)⋅log(-Σⁿᵢ₌₁⋅xᵢ - x_z + 1)

# %%
diff(idg_func, x_z)
# Out:
# log(x_z) - log(-Σⁿᵢ₌₁⋅xᵢ - x_z + 1)

# %%
diff(idg_func, x_z, x_z) # Validated against hand calculations
# Out:
#           1             1
# - ────────────────── + ───
#   Σⁿᵢ₌₁⋅xᵢ + x_z - 1   x_z

# %% [markdown]
# ## Pure component terms

# %%
g_i_R_k_func = x_z * (P * V_z_k / (R * T) - 1 - ln(P / (R * T)) - ln(V_z_k - b_z) - a_z /(R * T * V_z_k) )
g_i_R_k_func+= x_j * (P * V_j_k / (R * T) - 1 - ln(P / (R * T)) - ln(V_j_k - b_z) - a_j /(R * T * V_j_k) )
g_i_R_k_func+= Sigma_n_i * x_i * (P * V_i_k / (R * T) - 1 - ln(P / (R * T)) - ln(V_i_k - b_z) - a_i /(R * T * V_i_k) )
g_i_R_k_func
# Out:
#          ⎛P⋅V_i__k      ⎛ P ⎞                               aᵢ    ⎞       ⎛P⋅V_j__k
# Σⁿᵢ₌₁⋅xᵢ⋅⎜──────── - log⎜───⎟ - log(V_i__k - b_z) - 1 - ──────────⎟ + x_j⋅⎜──────── -
#          ⎝  R⋅T         ⎝R⋅T⎠                           R⋅T⋅V_i__k⎠       ⎝  R⋅T
#
#    ⎛ P ⎞                              a_j    ⎞       ⎛P⋅V_z__k      ⎛ P ⎞
# log⎜───⎟ - log(V_j__k - b_z) - 1 - ──────────⎟ + x_z⋅⎜──────── - log⎜───⎟ - log(V_z__k
#    ⎝R⋅T⎠                           R⋅T⋅V_j__k⎠       ⎝  R⋅T         ⎝R⋅T⎠
#
#                  a_z    ⎞
#  - b_z) - 1 - ──────────⎟
#               R⋅T⋅V_z__k⎠

# %%
g_i_R_k_func = g_i_R_k_func.subs(x_j, x_j_func )
g_i_R_k_func
# Out:
#          ⎛P⋅V_i__k      ⎛ P ⎞                               aᵢ    ⎞       ⎛P⋅V_z__k
# Σⁿᵢ₌₁⋅xᵢ⋅⎜──────── - log⎜───⎟ - log(V_i__k - b_z) - 1 - ──────────⎟ + x_z⋅⎜──────── -
#          ⎝  R⋅T         ⎝R⋅T⎠                           R⋅T⋅V_i__k⎠       ⎝  R⋅T
#
#    ⎛ P ⎞                              a_z    ⎞                         ⎛P⋅V_j__k
# log⎜───⎟ - log(V_z__k - b_z) - 1 - ──────────⎟ + (-Σⁿᵢ₌₁⋅xᵢ - x_z + 1)⋅⎜──────── - log
#    ⎝R⋅T⎠                           R⋅T⋅V_z__k⎠                         ⎝  R⋅T
#
# ⎛ P ⎞                              a_j    ⎞
# ⎜───⎟ - log(V_j__k - b_z) - 1 - ──────────⎟
# ⎝R⋅T⎠                           R⋅T⋅V_j__k⎠

# %%
diff(g_i_R_k_func, x_z) # Validated against hand calculations
# Out:
#   P⋅V_j__k   P⋅V_z__k                                              a_z          a_j
# - ──────── + ──────── + log(V_j__k - b_z) - log(V_z__k - b_z) - ────────── + ─────────
#     R⋅T        R⋅T                                              R⋅T⋅V_z__k   R⋅T⋅V_j__
#
#
# ─
# k

# %%
diff(g_i_R_k_func, x_z, x_z) # Validated against hand calculations
# Out:
# 0

# %% [markdown]
# ## Mixture Term

# %%
g_mix_R_k_func = P * V_mix_k(x_z) / (R * T) - 1 - ln(P / (R * T)) - ln(V_mix_k(x_z) - b_mix(x_z)) -  a_mix(x_z) /(R * T * V_mix_k(x_z))
g_mix_R_k_func
# Out:
# P⋅V_mix__k(x_z)      ⎛ P ⎞                                            aₘᵢₓ(x_z)
# ─────────────── - log⎜───⎟ - log(V_mix__k(x_z) - bₘᵢₓ(x_z)) - 1 - ─────────────────
#       R⋅T            ⎝R⋅T⎠                                        R⋅T⋅V_mix__k(x_z)

# %%
diff(g_mix_R_k_func, x_z) # Validated against hand calculations
# Out:
#    d                     d                     d                  d
# P⋅────(V_mix__k(x_z))   ────(V_mix__k(x_z)) - ────(bₘᵢₓ(x_z))    ────(aₘᵢₓ(x_z))    aₘ
#   dx_z                  dx_z                  dx_z               dx_z
# ───────────────────── - ───────────────────────────────────── - ───────────────── + ──
#          R⋅T                  V_mix__k(x_z) - bₘᵢₓ(x_z)         R⋅T⋅V_mix__k(x_z)
#
#
#          d
# ᵢₓ(x_z)⋅────(V_mix__k(x_z))
#         dx_z
# ───────────────────────────
#                 2
#     R⋅T⋅V_mix__k (x_z)

# %%
diff(g_mix_R_k_func, x_z, x_z) # TODO CHECK LATEX
# Out:
#      2                      2                      2
#     d                      d                      d
# P⋅─────(V_mix__k(x_z))   ─────(V_mix__k(x_z)) - ─────(bₘᵢₓ(x_z))   ⎛ d
#       2                      2                      2              ⎜────(V_mix__k(x_z)
#   dx_z                   dx_z                   dx_z               ⎝dx_z
# ────────────────────── - ─────────────────────────────────────── + ───────────────────
#          R⋅T                    V_mix__k(x_z) - bₘᵢₓ(x_z)
#                                                                          (V_mix__k(x_z
#
#                             2                            2
#                     2      d                            d
#      d             ⎞     ─────(aₘᵢₓ(x_z))   aₘᵢₓ(x_z)⋅─────(V_mix__k(x_z))      d
# ) - ────(bₘᵢₓ(x_z))⎟         2                            2                  2⋅────(V_
#     dx_z           ⎠     dx_z                         dx_z                     dx_z
# ───────────────────── - ───────────────── + ────────────────────────────── + ─────────
#               2         R⋅T⋅V_mix__k(x_z)                     2
# ) - bₘᵢₓ(x_z))                                    R⋅T⋅V_mix__k (x_z)
#
#
#                                                                 2
#               d                            ⎛ d                 ⎞
# mix__k(x_z))⋅────(aₘᵢₓ(x_z))   2⋅aₘᵢₓ(x_z)⋅⎜────(V_mix__k(x_z))⎟
#              dx_z                          ⎝dx_z               ⎠
# ──────────────────────────── - ──────────────────────────────────
#              2                                     3
#  R⋅T⋅V_mix__k (x_z)                    R⋅T⋅V_mix__k (x_z)

# %% [markdown]
# # Differential Functionals

# %% [markdown]
# ## a_mix

# %%
Sigma_n_i
# Out:
# Σⁿᵢ₌₁

# %% [markdown]
# ## b_mix practice

# %%
b_j, b_z, b_i, x_i, x_z = symbols('b_j, b_z, b_i, x_i, x_z')

# %%
b_mix_func = x_z * b_z + (1 - x_z - Sigma_n_i * x_i) * b_j + Sigma_n_i * x_i * b_i
b_mix_func
# Out:
# Σⁿᵢ₌₁⋅bᵢ⋅xᵢ + b_j⋅(-Σⁿᵢ₌₁⋅xᵢ - x_z + 1) + b_z⋅x_z

# %%
diff(b_mix_func , x_z) # Validated against hand calculations
# Out:
# -b_j + b_z

# %%
diff(b_mix_func , x_z, x_z) # Validated against hand calculations
# Out:
# 0

# %% [markdown]
# # Volume Terms

# %% [markdown]
# ######  (Here be Dragons)

# %%
C_1 = - ( (R * T / P) + b_mix(x_z))
C_2 = a_mix(x_z) / P
C_3 = - (a_mix(x_z) * b_mix(x_z)) / P

# %%
w = (3 * C_2 - C_1 **2) /3.0
w
# Out:
#                                       2
#                     ⎛             R⋅T⎞    1.0⋅aₘᵢₓ(x_z)
# - 0.333333333333333⋅⎜-bₘᵢₓ(x_z) - ───⎟  + ─────────────
#                     ⎝              P ⎠          P

# %%
q = (27 * C_3 - 9 * C_1 * C_2 + 2 * C_2 **3) / 27.0
q
# Out:
#                     ⎛               9⋅R⋅T⎞
#   0.037037037037037⋅⎜-9⋅bₘᵢₓ(x_z) - ─────⎟⋅aₘᵢₓ(x_z)
#                     ⎝                 P  ⎠             aₘᵢₓ(x_z)⋅bₘᵢₓ(x_z)   0.0740740
# - ────────────────────────────────────────────────── - ─────────────────── + ─────────
#                           P                                     P
#
#
#
#               3
# 740740741⋅aₘᵢₓ (x_z)
# ────────────────────
#       3
#      P

# %%
q_s = q /abs(q) # math.copysign
q_s
# Out:
#                      ⎛               9⋅R⋅T⎞
#    0.037037037037037⋅⎜-9⋅bₘᵢₓ(x_z) - ─────⎟⋅aₘᵢₓ(x_z)
#                      ⎝                 P  ⎠             aₘᵢₓ(x_z)⋅bₘᵢₓ(x_z)   0.074074
#  - ────────────────────────────────────────────────── - ─────────────────── + ────────
#                            P                                     P
#
# ──────────────────────────────────────────────────────────────────────────────────────
# │                    ⎛               9⋅R⋅T⎞
# │  0.037037037037037⋅⎜-9⋅bₘᵢₓ(x_z) - ─────⎟⋅aₘᵢₓ(x_z)
# │                    ⎝                 P  ⎠             aₘᵢₓ(x_z)⋅bₘᵢₓ(x_z)   0.074074
# │- ────────────────────────────────────────────────── - ─────────────────── + ────────
# │                          P                                     P
# │
#
#
#                3
# 0740740741⋅aₘᵢₓ (x_z)
# ─────────────────────
#        3
#       P
# ──────────────────────
#                      │
#                3     │
# 0740740741⋅aₘᵢₓ (x_z)│
# ─────────────────────│
#        3             │
#       P              │

# %%
#from math import acos
phi = acos(sqrt(( ((q/2.0)**2)/(w/3.0)**3) ))
phi
# Out:
#     ⎛                               __________________________________________________
#     ⎜                              ╱
#     ⎜                             ╱  ⎛                    ⎛               9⋅R⋅T⎞
#     ⎜                            ╱   ⎜  0.037037037037037⋅⎜-9⋅bₘᵢₓ(x_z) - ─────⎟⋅aₘᵢₓ(
#     ⎜                           ╱    ⎜                    ⎝                 P  ⎠
#     ⎜                          ╱     ⎜- ──────────────────────────────────────────────
#     ⎜                         ╱      ⎜                          P
#     ⎜                        ╱       ⎝
# acos⎜2.59807621135332⋅      ╱        ─────────────────────────────────────────────────
#     ⎜                      ╱
#     ⎜                     ╱                                      ⎛
#     ⎜                    ╱                                       ⎜
#     ⎜                   ╱                                        ⎜- 0.333333333333333⋅
#     ⎝                 ╲╱                                         ⎝
#
# _____________________________________________________________⎞
#                                                            2 ⎟
#                                                           ⎞  ⎟
# x_z)                                                3     ⎟  ⎟
#        aₘᵢₓ(x_z)⋅bₘᵢₓ(x_z)   0.0740740740740741⋅aₘᵢₓ (x_z)⎟  ⎟
# ──── - ─────────────────── + ─────────────────────────────⎟  ⎟
#                 P                           3             ⎟  ⎟
#                                            P              ⎠  ⎟
# ──────────────────────────────────────────────────────────── ⎟
#                                 3                            ⎟
#                   2            ⎞                             ⎟
# ⎛             R⋅T⎞    aₘᵢₓ(x_z)⎟                             ⎟
# ⎜-bₘᵢₓ(x_z) - ───⎟  + ─────────⎟                             ⎟
# ⎝              P ⎠        P    ⎠                             ⎠

# %%
f_1 = - 2 * q_s * sqrt(- w / 3.0) * cos(phi/3.0) - C_1/3.0
f_1
# Out:
#
#
#
#
#
#                         ___________________________________________________ ⎛
#                        ╱                                     2              ⎜  0.03703
#                       ╱                    ⎛             R⋅T⎞    aₘᵢₓ(x_z)  ⎜
#   1.15470053837925⋅  ╱   0.333333333333333⋅⎜-bₘᵢₓ(x_z) - ───⎟  - ───────── ⋅⎜- ───────
#                    ╲╱                      ⎝              P ⎠        P      ⎜
#                                                                             ⎝
#
#
#
# - ────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#            ⎛               9⋅R⋅T⎞
# 7037037037⋅⎜-9⋅bₘᵢₓ(x_z) - ─────⎟⋅aₘᵢₓ(x_z)
#            ⎝                 P  ⎠             aₘᵢₓ(x_z)⋅bₘᵢₓ(x_z)   0.0740740740740741
# ─────────────────────────────────────────── - ─────────────────── + ──────────────────
#                  P                                     P                           3
#                                                                                   P
#
#
#
# ──────────────────────────────────────────────────────────────────────────────────────
#                                        │                    ⎛               9⋅R⋅T⎞
#                                        │  0.037037037037037⋅⎜-9⋅bₘᵢₓ(x_z) - ─────⎟⋅aₘᵢ
#                                        │                    ⎝                 P  ⎠
#                                        │- ────────────────────────────────────────────
#                                        │                          P
#                                        │
#
#                 ⎛                      ⎛                               _______________
#                 ⎜                      ⎜                              ╱
#                 ⎜                      ⎜                             ╱  ⎛
#                 ⎜                      ⎜                            ╱   ⎜  0.037037037
#                 ⎜                      ⎜                           ╱    ⎜
#            ⎞    ⎜                      ⎜                          ╱     ⎜- ───────────
#      3     ⎟    ⎜                      ⎜                         ╱      ⎜
# ⋅aₘᵢₓ (x_z)⎟    ⎜                      ⎜                        ╱       ⎝
# ───────────⎟⋅cos⎜0.333333333333333⋅acos⎜2.59807621135332⋅      ╱        ──────────────
#            ⎟    ⎜                      ⎜                      ╱
#            ⎠    ⎜                      ⎜                     ╱
#                 ⎜                      ⎜                    ╱
#                 ⎜                      ⎜                   ╱
#                 ⎝                      ⎝                 ╲╱
# ──────────────────────────────────────────────────────────────────────────────────────
#                                                             │
# ₓ(x_z)                                                3     │
#          aₘᵢₓ(x_z)⋅bₘᵢₓ(x_z)   0.0740740740740741⋅aₘᵢₓ (x_z)│
# ────── - ─────────────────── + ─────────────────────────────│
#                   P                           3             │
#                                              P              │
#
# ______________________________________________________________________________________
#
#        ⎛               9⋅R⋅T⎞
# 037037⋅⎜-9⋅bₘᵢₓ(x_z) - ─────⎟⋅aₘᵢₓ(x_z)
#        ⎝                 P  ⎠             aₘᵢₓ(x_z)⋅bₘᵢₓ(x_z)   0.0740740740740741⋅aₘᵢ
# ─────────────────────────────────────── - ─────────────────── + ──────────────────────
#              P                                     P                           3
#                                                                               P
# ──────────────────────────────────────────────────────────────────────────────────────
#                                                                    3
#               ⎛                                      2            ⎞
#               ⎜                    ⎛             R⋅T⎞    aₘᵢₓ(x_z)⎟
#               ⎜- 0.333333333333333⋅⎜-bₘᵢₓ(x_z) - ───⎟  + ─────────⎟
#               ⎝                    ⎝              P ⎠        P    ⎠
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
# __________⎞⎞
#         2 ⎟⎟
#        ⎞  ⎟⎟
#  3     ⎟  ⎟⎟
# ₓ (x_z)⎟  ⎟⎟
# ───────⎟  ⎟⎟
#        ⎟  ⎟⎟
#        ⎠  ⎟⎟
# ───────── ⎟⎟
#           ⎟⎟
#           ⎟⎟
#           ⎟⎟
#           ⎟⎟
#           ⎠⎠                                 0.333333333333333⋅R⋅T
# ──────────── + 0.333333333333333⋅bₘᵢₓ(x_z) + ─────────────────────
#                                                        P

# %%
diff(f_1, x_z)
# Out:
#                                  _____________________________________________________
#                                 ╱
#                                ╱  ⎛                    ⎛               9⋅R⋅T⎞
#                               ╱   ⎜  0.037037037037037⋅⎜-9⋅bₘᵢₓ(x_z) - ─────⎟⋅aₘᵢₓ(x_z
#                              ╱    ⎜                    ⎝                 P  ⎠
#                             ╱     ⎜- ─────────────────────────────────────────────────
#                            ╱      ⎜                          P
#                           ╱       ⎝
#   0.38490017945975⋅      ╱        ────────────────────────────────────────────────────
#                         ╱
#                        ╱                                      ⎛
#                       ╱                                       ⎜                    ⎛
#                      ╱                                        ⎜- 0.333333333333333⋅⎜-b
#                    ╲╱                                         ⎝                    ⎝
# - ────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# __________________________________________________________
#                                                         2  ⎛
#                                                        ⎞   ⎜⎛
# )                                                3     ⎟   ⎜⎜
#     aₘᵢₓ(x_z)⋅bₘᵢₓ(x_z)   0.0740740740740741⋅aₘᵢₓ (x_z)⎟   ⎜⎜      ⎛             R⋅T⎞
# ─ - ─────────────────── + ─────────────────────────────⎟   ⎜⎜- 2.0⋅⎜-bₘᵢₓ(x_z) - ───⎟⋅
#              P                           3             ⎟   ⎜⎝      ⎝              P ⎠
#                                         P              ⎠   ⎜
# ───────────────────────────────────────────────────────── ⋅⎜──────────────────────────
#                              3                             ⎜
#                2            ⎞                              ⎜
#            R⋅T⎞    aₘᵢₓ(x_z)⎟                              ⎜
# ₘᵢₓ(x_z) - ───⎟  + ─────────⎟                              ⎜
#             P ⎠        P    ⎠                              ⎝
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                      d             ⎞ ⎛                    ⎛               9⋅R⋅T⎞
#                   3⋅────(aₘᵢₓ(x_z))⎟ ⎜  0.037037037037037⋅⎜-9⋅bₘᵢₓ(x_z) - ─────⎟⋅aₘᵢₓ(
#  d                  dx_z           ⎟ ⎜                    ⎝                 P  ⎠
# ────(bₘᵢₓ(x_z)) - ─────────────────⎟⋅⎜- ──────────────────────────────────────────────
# dx_z                      P        ⎠ ⎜                          P
#                                      ⎝
# ──────────────────────────────────────────────────────────────────────────────────────
#
#                                   ⎛                                      2
#                                   ⎜                    ⎛             R⋅T⎞    aₘᵢₓ(x_z)
#                                 2⋅⎜- 0.333333333333333⋅⎜-bₘᵢₓ(x_z) - ───⎟  + ─────────
#                                   ⎝                    ⎝              P ⎠        P
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                            2
#                                                           ⎞    ⎛                    ⎛
# x_z)                                                3     ⎟    ⎜  0.037037037037037⋅⎜-
#        aₘᵢₓ(x_z)⋅bₘᵢₓ(x_z)   0.0740740740740741⋅aₘᵢₓ (x_z)⎟    ⎜                    ⎝
# ──── - ─────────────────── + ─────────────────────────────⎟    ⎜- ────────────────────
#                 P                           3             ⎟    ⎜
#                                            P              ⎠    ⎝
# ──────────────────────────────────────────────────────────── + ───────────────────────
#  4
# ⎞
# ⎟
# ⎟
# ⎠
# ──────────────────────────────────────────────────────────────────────────────────────
#                                                                                _______
#                                                                               ╱
#                                                                              ╱
#                                                                             ╱
#                                                                            ╱
#                                                                           ╱
#                                                                          ╱
#                                                                         ╱
#                                                                        ╱        0.1481
#                                                                       ╱
#                                                                      ╱
#                                                                     ╱
#                                                                    ╱
#                                                                  ╲╱
#
#
#
#               9⋅R⋅T⎞                                                                ⎞
# 9⋅bₘᵢₓ(x_z) - ─────⎟⋅aₘᵢₓ(x_z)                                                3     ⎟
#                 P  ⎠             aₘᵢₓ(x_z)⋅bₘᵢₓ(x_z)   0.0740740740740741⋅aₘᵢₓ (x_z)⎟
# ────────────────────────────── - ─────────────────── + ─────────────────────────────⎟⋅
#     P                                     P                           3             ⎟
#                                                                      P              ⎠
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________________
#
#               ⎛                    ⎛               9⋅R⋅T⎞
#               ⎜  0.037037037037037⋅⎜-9⋅bₘᵢₓ(x_z) - ─────⎟⋅aₘᵢₓ(x_z)
#               ⎜                    ⎝                 P  ⎠             aₘᵢₓ(x_z)⋅bₘᵢₓ(x
#               ⎜- ────────────────────────────────────────────────── - ────────────────
#               ⎜                          P                                     P
#               ⎝
# 48148148148 - ────────────────────────────────────────────────────────────────────────
#
#                                           ⎛                                      2
#                                           ⎜                    ⎛             R⋅T⎞    a
#                                           ⎜- 0.333333333333333⋅⎜-bₘᵢₓ(x_z) - ───⎟  + ─
#                                           ⎝                    ⎝              P ⎠
#
#
#
# ⎛                     ⎛               9⋅R⋅T⎞  d
# ⎜  0.0740740740740741⋅⎜-9⋅bₘᵢₓ(x_z) - ─────⎟⋅────(aₘᵢₓ(x_z))   1.33333333333333⋅aₘᵢₓ(x
# ⎜                     ⎝                 P  ⎠ dx_z
# ⎜- ───────────────────────────────────────────────────────── - ───────────────────────
# ⎜                              P                                                   P
# ⎝
# ──────────────────────────────────────────────────────────────────────────────────────
#                                                                 3
#            ⎛                                      2            ⎞
#            ⎜                    ⎛             R⋅T⎞    aₘᵢₓ(x_z)⎟
#          2⋅⎜- 0.333333333333333⋅⎜-bₘᵢₓ(x_z) - ───⎟  + ─────────⎟
#            ⎝                    ⎝              P ⎠        P    ⎠
# ──────────────────────────────────────────────────────────────────────────────────────
# ______________________________________
#                                     2
#                                    ⎞
#                              3     ⎟
# _z)   0.0740740740740741⋅aₘᵢₓ (x_z)⎟
# ─── + ─────────────────────────────⎟   ⎛                    ⎛               9⋅R⋅T⎞
#                      3             ⎟   ⎜  0.037037037037037⋅⎜-9⋅bₘᵢₓ(x_z) - ─────⎟⋅aₘᵢ
#                     P              ⎠   ⎜                    ⎝                 P  ⎠
# ───────────────────────────────────── ⋅⎜- ────────────────────────────────────────────
#          3                             ⎜                          P
#         ⎞                              ⎝
# ₘᵢₓ(x_z)⎟
# ────────⎟
#    P    ⎠
#
#
#
#      d                             d                                      2       d
# _z)⋅────(bₘᵢₓ(x_z))   2⋅bₘᵢₓ(x_z)⋅────(aₘᵢₓ(x_z))   0.444444444444444⋅aₘᵢₓ (x_z)⋅────(
#     dx_z                          dx_z                                           dx_z
# ─────────────────── - ─────────────────────────── + ──────────────────────────────────
#                                    P                                      3
#                                                                          P
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                                              2
#                                                             ⎞  │                    ⎛
# ₓ(x_z)                                                3     ⎟  │  0.037037037037037⋅⎜-
#          aₘᵢₓ(x_z)⋅bₘᵢₓ(x_z)   0.0740740740740741⋅aₘᵢₓ (x_z)⎟  │                    ⎝
# ────── - ─────────────────── + ─────────────────────────────⎟ ⋅│- ────────────────────
#                   P                           3             ⎟  │
#                                              P              ⎠  │
#
#
#
#
#
#            ⎞
#           ⎞⎟
# aₘᵢₓ(x_z))⎟⎟
#           ⎟⎟
# ──────────⎟⎟                                                      3      _____________
#           ⎟⎟ ⎛                                      2            ⎞      ╱
#           ⎠⎟ ⎜                    ⎛             R⋅T⎞    aₘᵢₓ(x_z)⎟     ╱
# ───────────⎟⋅⎜- 0.333333333333333⋅⎜-bₘᵢₓ(x_z) - ───⎟  + ─────────⎟ ⋅  ╱   0.3333333333
#            ⎟ ⎝                    ⎝              P ⎠        P    ⎠  ╲╱
#            ⎟
#            ⎟
#            ⎟
#            ⎠
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#               9⋅R⋅T⎞                                                                │
# 9⋅bₘᵢₓ(x_z) - ─────⎟⋅aₘᵢₓ(x_z)                                                3     │
#                 P  ⎠             aₘᵢₓ(x_z)⋅bₘᵢₓ(x_z)   0.0740740740740741⋅aₘᵢₓ (x_z)│
# ────────────────────────────── - ─────────────────── + ─────────────────────────────│
#     P                                     P                           3             │
#                                                                      P              │
#
#
#
#
#
#
#
#
#
# ______________________________________ ⎛                    ⎛               9⋅R⋅T⎞
#                         2              ⎜  0.037037037037037⋅⎜-9⋅bₘᵢₓ(x_z) - ─────⎟⋅aₘᵢ
#       ⎛             R⋅T⎞    aₘᵢₓ(x_z)  ⎜                    ⎝                 P  ⎠
# 33333⋅⎜-bₘᵢₓ(x_z) - ───⎟  - ───────── ⋅⎜- ────────────────────────────────────────────
#       ⎝              P ⎠        P      ⎜                          P
#                                        ⎝
#
#
#
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                                  ⎛
#                                                                  ⎜
#                                                                  ⎜
#                                                                  ⎜
#                                                                  ⎜
#                                                             ⎞    ⎜
# ₓ(x_z)                                                3     ⎟    ⎜
#          aₘᵢₓ(x_z)⋅bₘᵢₓ(x_z)   0.0740740740740741⋅aₘᵢₓ (x_z)⎟    ⎜
# ────── - ─────────────────── + ─────────────────────────────⎟⋅sin⎜0.333333333333333⋅ac
#                   P                           3             ⎟    ⎜
#                                              P              ⎠    ⎜
#                                                                  ⎜
#                                                                  ⎜
#                                                                  ⎝
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   ⎛                               ____________________________________________________
#   ⎜                              ╱
#   ⎜                             ╱  ⎛                    ⎛               9⋅R⋅T⎞
#   ⎜                            ╱   ⎜  0.037037037037037⋅⎜-9⋅bₘᵢₓ(x_z) - ─────⎟⋅aₘᵢₓ(x_
#   ⎜                           ╱    ⎜                    ⎝                 P  ⎠
#   ⎜                          ╱     ⎜- ────────────────────────────────────────────────
#   ⎜                         ╱      ⎜                          P
#   ⎜                        ╱       ⎝
# os⎜2.59807621135332⋅      ╱        ───────────────────────────────────────────────────
#   ⎜                      ╱
#   ⎜                     ╱                                      ⎛
#   ⎜                    ╱                                       ⎜                    ⎛
#   ⎜                   ╱                                        ⎜- 0.333333333333333⋅⎜-
#   ⎝                 ╲╱                                         ⎝                    ⎝
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ___________________________________________________________⎞⎞
#                                                          2 ⎟⎟
#                                                         ⎞  ⎟⎟
# z)                                                3     ⎟  ⎟⎟
#      aₘᵢₓ(x_z)⋅bₘᵢₓ(x_z)   0.0740740740740741⋅aₘᵢₓ (x_z)⎟  ⎟⎟
# ── - ─────────────────── + ─────────────────────────────⎟  ⎟⎟                    ⎛
#               P                           3             ⎟  ⎟⎟                    ⎜
#                                          P              ⎠  ⎟⎟                    ⎜
# ────────────────────────────────────────────────────────── ⎟⎟   1.15470053837925⋅⎜- 0.
#                               3                            ⎟⎟                    ⎝
#                 2            ⎞                             ⎟⎟
#             R⋅T⎞    aₘᵢₓ(x_z)⎟                             ⎟⎟
# bₘᵢₓ(x_z) - ───⎟  + ─────────⎟                             ⎟⎟
#              P ⎠        P    ⎠                             ⎠⎠
# ───────────────────────────────────────────────────────────── - ──────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                       d             ⎞ ⎛
#                                                      ────(aₘᵢₓ(x_z))⎟ ⎜  0.03703703703
#                 ⎛             R⋅T⎞  d                dx_z           ⎟ ⎜
# 333333333333333⋅⎜-bₘᵢₓ(x_z) - ───⎟⋅────(bₘᵢₓ(x_z)) - ───────────────⎟⋅⎜- ─────────────
#                 ⎝              P ⎠ dx_z                    2⋅P      ⎠ ⎜
#                                                                       ⎝
#
#
#
# ──────────────────────────────────────────────────────────────────────────────────────
#
#                                                                                      ╱
#                                                                                     ╱
#                                                                                    ╱
#                                                                                  ╲╱
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#      ⎛               9⋅R⋅T⎞
# 7037⋅⎜-9⋅bₘᵢₓ(x_z) - ─────⎟⋅aₘᵢₓ(x_z)                                                3
#      ⎝                 P  ⎠             aₘᵢₓ(x_z)⋅bₘᵢₓ(x_z)   0.0740740740740741⋅aₘᵢₓ
# ───────────────────────────────────── - ─────────────────── + ────────────────────────
#            P                                     P                           3
#                                                                             P
#
#
#
# ──────────────────────────────────────────────────────────────────────────────────────
# ___________________________________________________ │                    ⎛
#                                      2              │  0.037037037037037⋅⎜-9⋅bₘᵢₓ(x_z)
#                    ⎛             R⋅T⎞    aₘᵢₓ(x_z)  │                    ⎝
#  0.333333333333333⋅⎜-bₘᵢₓ(x_z) - ───⎟  - ───────── ⋅│- ───────────────────────────────
#                    ⎝              P ⎠        P      │                          P
#                                                     │
#
#
#
#
#
#
#
#
#
#           ⎛                      ⎛                               _____________________
#           ⎜                      ⎜                              ╱
#           ⎜                      ⎜                             ╱  ⎛
#           ⎜                      ⎜                            ╱   ⎜  0.037037037037037
#           ⎜                      ⎜                           ╱    ⎜
#      ⎞    ⎜                      ⎜                          ╱     ⎜- ─────────────────
#      ⎟    ⎜                      ⎜                         ╱      ⎜
# (x_z)⎟    ⎜                      ⎜                        ╱       ⎝
# ─────⎟⋅cos⎜0.333333333333333⋅acos⎜2.59807621135332⋅      ╱        ────────────────────
#      ⎟    ⎜                      ⎜                      ╱
#      ⎠    ⎜                      ⎜                     ╱
#           ⎜                      ⎜                    ╱
#           ⎜                      ⎜                   ╱
#           ⎝                      ⎝                 ╲╱
# ──────────────────────────────────────────────────────────────────────────────────────
#    9⋅R⋅T⎞                                                                │
#  - ─────⎟⋅aₘᵢₓ(x_z)                                                3     │
#      P  ⎠             aₘᵢₓ(x_z)⋅bₘᵢₓ(x_z)   0.0740740740740741⋅aₘᵢₓ (x_z)│
# ─────────────────── - ─────────────────── + ─────────────────────────────│
#                                P                           3             │
#                                                           P              │
#
#
#
#
#
#
#
#
#
# ______________________________________________________________________________________
#
#  ⎛               9⋅R⋅T⎞
# ⋅⎜-9⋅bₘᵢₓ(x_z) - ─────⎟⋅aₘᵢₓ(x_z)                                                3
#  ⎝                 P  ⎠             aₘᵢₓ(x_z)⋅bₘᵢₓ(x_z)   0.0740740740740741⋅aₘᵢₓ (x_z
# ───────────────────────────────── - ─────────────────── + ────────────────────────────
#        P                                     P                           3
#                                                                         P
# ──────────────────────────────────────────────────────────────────────────────────────
#                                                              3
#         ⎛                                      2            ⎞
#         ⎜                    ⎛             R⋅T⎞    aₘᵢₓ(x_z)⎟
#         ⎜- 0.333333333333333⋅⎜-bₘᵢₓ(x_z) - ───⎟  + ─────────⎟
#         ⎝                    ⎝              P ⎠        P    ⎠
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ____⎞⎞
#   2 ⎟⎟
#  ⎞  ⎟⎟
#  ⎟  ⎟⎟
# )⎟  ⎟⎟
# ─⎟  ⎟⎟
#  ⎟  ⎟⎟                    ⎛⎛
#  ⎠  ⎟⎟                    ⎜⎜                    ⎛      ⎛R⋅T⎞                  ⎞   ⎛aₘᵢ
# ─── ⎟⎟   1.15470053837925⋅⎜⎜- 0.037037037037037⋅⎜- 9⋅re⎜───⎟ - 9⋅re(bₘᵢₓ(x_z))⎟⋅re⎜───
#     ⎟⎟                    ⎜⎜                    ⎝      ⎝ P ⎠                  ⎠   ⎝
#     ⎟⎟                    ⎝⎝
#     ⎟⎟
#     ⎟⎟
#     ⎠⎠
# ────── + ─────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ₓ(x_z)⎞                     ⎛      ⎛R⋅T⎞                  ⎞   ⎛aₘᵢₓ(x_z)⎞
# ──────⎟ + 0.037037037037037⋅⎜- 9⋅im⎜───⎟ - 9⋅im(bₘᵢₓ(x_z))⎟⋅im⎜─────────⎟ + 0.07407407
#  P    ⎠                     ⎝      ⎝ P ⎠                  ⎠   ⎝    P    ⎠
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#            ⎛    3     ⎞                          ⎞ ⎛
#            ⎜aₘᵢₓ (x_z)⎟     ⎛aₘᵢₓ(x_z)⋅bₘᵢₓ(x_z)⎞⎟ ⎜⎛                    ⎛R⋅T⎞
# 40740741⋅re⎜──────────⎟ - re⎜───────────────────⎟⎟⋅⎜⎜0.333333333333333⋅re⎜───⎟ + 0.333
#            ⎜     3    ⎟     ⎝         P         ⎠⎟ ⎜⎝                    ⎝ P ⎠
#            ⎝    P     ⎠                          ⎠ ⎝
#
#
#
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
#
#
#
#
#
#
#
#
#   ⎛               9⋅R⋅T⎞
# 7⋅⎜-9⋅bₘᵢₓ(x_z) - ─────⎟⋅aₘᵢₓ(x_z)                                                3
#   ⎝                 P  ⎠             aₘᵢₓ(x_z)⋅bₘᵢₓ(x_z)   0.0740740740740741⋅aₘᵢₓ (x_
# ────────────────────────────────── - ─────────────────── + ───────────────────────────
#         P                                     P                           3
#                                                                          P
#
#
#
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   ⎞                         ___________________________________________________ ⎛
#   ⎟                        ╱                                     2              ⎜  0.0
# z)⎟                       ╱                    ⎛             R⋅T⎞    aₘᵢₓ(x_z)  ⎜
# ──⎟   1.15470053837925⋅  ╱   0.333333333333333⋅⎜-bₘᵢₓ(x_z) - ───⎟  - ───────── ⋅⎜- ───
#   ⎟                    ╲╱                      ⎝              P ⎠        P      ⎜
#   ⎠                                                                             ⎝
#
#
#
# ─── - ────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                ⎛               9⋅R⋅T⎞  d                                             d
# 37037037037037⋅⎜-9⋅bₘᵢₓ(x_z) - ─────⎟⋅────(aₘᵢₓ(x_z))   0.666666666666667⋅aₘᵢₓ(x_z)⋅──
#                ⎝                 P  ⎠ dx_z                                          dx
# ───────────────────────────────────────────────────── - ──────────────────────────────
#                         P                                                    P
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────────────
#                                                                                 │
#                                                                                 │  0.0
#                                                                                 │
#                                                                                 │- ───
#                                                                                 │
#                                                                                 │
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                            d                                      2       d
# ──(bₘᵢₓ(x_z))   bₘᵢₓ(x_z)⋅────(aₘᵢₓ(x_z))   0.222222222222222⋅aₘᵢₓ (x_z)⋅────(aₘᵢₓ(x_z
# _z                        dx_z                                           dx_z
# ───────────── - ───────────────────────── + ──────────────────────────────────────────
#                             P                                     3
#                                                                  P
#
#
#
# ──────────────────────────────────────────────────────────────────────────────────────
#                ⎛               9⋅R⋅T⎞
# 37037037037037⋅⎜-9⋅bₘᵢₓ(x_z) - ─────⎟⋅aₘᵢₓ(x_z)
#                ⎝                 P  ⎠             aₘᵢₓ(x_z)⋅bₘᵢₓ(x_z)   0.074074074074
# ─────────────────────────────────────────────── - ─────────────────── + ──────────────
#                      P                                     P
#
#
#
#
#
#
#
#
#
#
#        ⎛                      ⎛                               ________________________
#        ⎜                      ⎜                              ╱
#        ⎜                      ⎜                             ╱  ⎛                    ⎛
#        ⎜                      ⎜                            ╱   ⎜  0.037037037037037⋅⎜-
#        ⎜                      ⎜                           ╱    ⎜                    ⎝
#   ⎞    ⎜                      ⎜                          ╱     ⎜- ────────────────────
# ))⎟    ⎜                      ⎜                         ╱      ⎜
#   ⎟    ⎜                      ⎜                        ╱       ⎝
# ──⎟⋅cos⎜0.333333333333333⋅acos⎜2.59807621135332⋅      ╱        ───────────────────────
#   ⎟    ⎜                      ⎜                      ╱
#   ⎠    ⎜                      ⎜                     ╱
#        ⎜                      ⎜                    ╱
#        ⎜                      ⎜                   ╱
#        ⎝                      ⎝                 ╲╱
# ──────────────────────────────────────────────────────────────────────────────────────
#                │
#          3     │
# 0741⋅aₘᵢₓ (x_z)│
# ───────────────│
#  3             │
# P              │
#
#
#
#
#
#
#
#
#
# ______________________________________________________________________________________
#                                                                                      2
#               9⋅R⋅T⎞                                                                ⎞
# 9⋅bₘᵢₓ(x_z) - ─────⎟⋅aₘᵢₓ(x_z)                                                3     ⎟
#                 P  ⎠             aₘᵢₓ(x_z)⋅bₘᵢₓ(x_z)   0.0740740740740741⋅aₘᵢₓ (x_z)⎟
# ────────────────────────────── - ─────────────────── + ─────────────────────────────⎟
#     P                                     P                           3             ⎟
#                                                                      P              ⎠
# ──────────────────────────────────────────────────────────────────────────────────────
#                                                           3
#      ⎛                                      2            ⎞
#      ⎜                    ⎛             R⋅T⎞    aₘᵢₓ(x_z)⎟
#      ⎜- 0.333333333333333⋅⎜-bₘᵢₓ(x_z) - ───⎟  + ─────────⎟
#      ⎝                    ⎝              P ⎠        P    ⎠
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# _⎞⎞
#  ⎟⎟
#  ⎟⎟
#  ⎟⎟
#  ⎟⎟
#  ⎟⎟
#  ⎟⎟
#  ⎟⎟
#  ⎟⎟
#  ⎟⎟
#  ⎟⎟
#  ⎟⎟
#  ⎟⎟
#  ⎠⎠                      d
# ─── + 0.333333333333333⋅────(bₘᵢₓ(x_z))
#                         dx_z

# %% [markdown]
# ## Functional approach

# %% [markdown]
# ######  # TO DO Group these functions into simpler expressions for final implementation

# %%
w, q, q_s, phi, C_1, C_2, C_3 = symbols('w, q, q_s, phi, C_1, C_2, C_3', cls=Function)

# %% [markdown]
# ### $f_1$

# %%
f_1 = - Rational(2) * q_s(x_z) * sqrt(- w(x_z) / Rational(3.0)) * cos(phi(x_z)/Rational(3.0)) - C_1(x_z)/Rational(3.0)
f_1
# Out:
#          _________            ⎛φ(x_z)⎞
#   2⋅√3⋅╲╱ -w(x_z) ⋅qₛ(x_z)⋅cos⎜──────⎟
#                               ⎝  3   ⎠   C₁(x_z)
# - ──────────────────────────────────── - ───────
#                    3                        3

# %% [markdown]
# ### $\frac{d}{dx_z} \left(  f_1\right)$

# %%
diff(f_1, x_z)
# Out:
#        _________            ⎛φ(x_z)⎞  d                  _________            ⎛φ(x_z)⎞
# 2⋅√3⋅╲╱ -w(x_z) ⋅qₛ(x_z)⋅sin⎜──────⎟⋅────(φ(x_z))   √3⋅╲╱ -w(x_z) ⋅qₛ(x_z)⋅cos⎜──────⎟
#                             ⎝  3   ⎠ dx_z                                     ⎝  3   ⎠
# ───────────────────────────────────────────────── - ──────────────────────────────────
#                         9                                               3⋅w(x_z)
#
#   d                    _________    ⎛φ(x_z)⎞  d               d
# ⋅────(w(x_z))   2⋅√3⋅╲╱ -w(x_z) ⋅cos⎜──────⎟⋅────(qₛ(x_z))   ────(C₁(x_z))
#  dx_z                               ⎝  3   ⎠ dx_z            dx_z
# ───────────── - ────────────────────────────────────────── - ─────────────
#                                     3                              3

# %% [markdown]
# ### $\frac{d^2}{dx_z^2} \left(  f_1\right)$

# %%
diff(f_1, x_z, x_z)
# Out:
#
#
#
#                                          2
#         _________            ⎛φ(x_z)⎞   d                    _________            ⎛φ(x
# 12⋅√3⋅╲╱ -w(x_z) ⋅qₛ(x_z)⋅sin⎜──────⎟⋅─────(φ(x_z)) + 4⋅√3⋅╲╱ -w(x_z) ⋅qₛ(x_z)⋅cos⎜───
#                              ⎝  3   ⎠     2                                       ⎝  3
#                                       dx_z
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                _________            ⎛φ(x_z)⎞  d            d
#                    2   12⋅√3⋅╲╱ -w(x_z) ⋅qₛ(x_z)⋅sin⎜──────⎟⋅────(φ(x_z))⋅────(w(x_z))
# _z)⎞ ⎛ d          ⎞                                 ⎝  3   ⎠ dx_z         dx_z
# ───⎟⋅⎜────(φ(x_z))⎟  + ───────────────────────────────────────────────────────────────
#    ⎠ ⎝dx_z        ⎠                                 w(x_z)
#
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
#                                             2
#            _________            ⎛φ(x_z)⎞   d
#    18⋅√3⋅╲╱ -w(x_z) ⋅qₛ(x_z)⋅cos⎜──────⎟⋅─────(w(x_z))          _________            ⎛
#                                 ⎝  3   ⎠     2           9⋅√3⋅╲╱ -w(x_z) ⋅qₛ(x_z)⋅cos⎜
#                                          dx_z                                        ⎝
#  - ─────────────────────────────────────────────────── + ─────────────────────────────
#                           w(x_z)                                                2
#                                                                                w (x_z)
# ──────────────────────────────────────────────────────────────────────────────────────
#                                                             54
#
#
#                       2
# φ(x_z)⎞ ⎛ d          ⎞
# ──────⎟⋅⎜────(w(x_z))⎟
#   3   ⎠ ⎝dx_z        ⎠            _________    ⎛φ(x_z)⎞  d            d
# ─────────────────────── + 24⋅√3⋅╲╱ -w(x_z) ⋅sin⎜──────⎟⋅────(φ(x_z))⋅────(qₛ(x_z)) - 3
#                                                ⎝  3   ⎠ dx_z         dx_z
#
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                                       _________    ⎛φ(x_z)⎞  d
#                                 2             36⋅√3⋅╲╱ -w(x_z) ⋅cos⎜──────⎟⋅────(qₛ(x_
#        _________    ⎛φ(x_z)⎞   d                                   ⎝  3   ⎠ dx_z
# 6⋅√3⋅╲╱ -w(x_z) ⋅cos⎜──────⎟⋅─────(qₛ(x_z)) - ────────────────────────────────────────
#                     ⎝  3   ⎠     2                                     w(x_z)
#                              dx_z
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#      d
# z))⋅────(w(x_z))         2
#     dx_z                d
# ──────────────── - 18⋅─────(C₁(x_z))
#                           2
#                       dx_z
# ────────────────────────────────────

# %%
diff(f_1, x_z, x_z).simplify()
# Out:
#                ⎛
#      _________ ⎜             ⎛φ(x_z)⎞  d            d                          ⎛φ(x_z)
# √3⋅╲╱ -w(x_z) ⋅⎜2⋅qₛ(x_z)⋅sin⎜──────⎟⋅────(φ(x_z))⋅────(w(x_z)) - 3⋅qₛ(x_z)⋅cos⎜──────
#                ⎜             ⎝  3   ⎠ dx_z         dx_z                        ⎝  3
#                ⎝
# ──────────────────────────────────────────────────────────────────────────────────────
#                                                                            9
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
#
#      2                                                    ⎞
# ⎞   d                  ⎛φ(x_z)⎞  d             d          ⎟
# ⎟⋅─────(w(x_z)) - 6⋅cos⎜──────⎟⋅────(qₛ(x_z))⋅────(w(x_z))⎟⋅w(x_z)        _________
# ⎠     2                ⎝  3   ⎠ dx_z          dx_z        ⎟          √3⋅╲╱ -w(x_z) ⋅qₛ
#   dx_z                                                    ⎠
# ────────────────────────────────────────────────────────────────── + ─────────────────
#
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
#
#                                     ⎛                                         2
#                                 2   ⎜        _________            ⎛φ(x_z)⎞   d
#          ⎛φ(x_z)⎞ ⎛ d          ⎞    ⎜12⋅√3⋅╲╱ -w(x_z) ⋅qₛ(x_z)⋅sin⎜──────⎟⋅─────(φ(x_z
# (x_z)⋅cos⎜──────⎟⋅⎜────(w(x_z))⎟    ⎜                             ⎝  3   ⎠     2
#          ⎝  3   ⎠ ⎝dx_z        ⎠    ⎝                                      dx_z
# ───────────────────────────────── + ──────────────────────────────────────────────────
#        6
# ──────────────────────────────────────────────────────────────────────────────────────
#                                                   2
#                                                  w (x_z)
#
#                                                         2
#             _________            ⎛φ(x_z)⎞ ⎛ d          ⎞            _________    ⎛φ(x_
# )) + 4⋅√3⋅╲╱ -w(x_z) ⋅qₛ(x_z)⋅cos⎜──────⎟⋅⎜────(φ(x_z))⎟  + 24⋅√3⋅╲╱ -w(x_z) ⋅sin⎜────
#                                  ⎝  3   ⎠ ⎝dx_z        ⎠                         ⎝  3
#
# ──────────────────────────────────────────────────────────────────────────────────────
#                                                                       54
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
#
#                                                                   2
# z)⎞  d            d                      _________    ⎛φ(x_z)⎞   d                   d
# ──⎟⋅────(φ(x_z))⋅────(qₛ(x_z)) - 36⋅√3⋅╲╱ -w(x_z) ⋅cos⎜──────⎟⋅─────(qₛ(x_z)) - 18⋅───
#   ⎠ dx_z         dx_z                                 ⎝  3   ⎠     2
#                                                                dx_z                dx_
# ──────────────────────────────────────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
#
# 2          ⎞
#            ⎟  2
# ──(C₁(x_z))⎟⋅w (x_z)
#  2         ⎟
# z          ⎠
# ────────────────────
#
# ────────────────────

# %% [markdown]
# #### $f_2$

# %%
f_2 = - Rational(2) * q_s(x_z) * sqrt(- w(x_z) / Rational(3.0)) * cos(phi(x_z)/Rational(3.0) + 2 * pi /Rational(3.0)) - C_1(x_z)/Rational(3.0)
f_2
# Out:
#        _________            ⎛φ(x_z)   π⎞
# 2⋅√3⋅╲╱ -w(x_z) ⋅qₛ(x_z)⋅sin⎜────── + ─⎟
#                             ⎝  3      6⎠   C₁(x_z)
# ──────────────────────────────────────── - ───────
#                    3                          3

# %% [markdown]
# ### $\frac{d}{dx_z} \left(  f_2\right)$

# %%
diff(f_2, x_z)
# Out:
#        _________            ⎛φ(x_z)   π⎞  d                  _________            ⎛φ(x
# 2⋅√3⋅╲╱ -w(x_z) ⋅qₛ(x_z)⋅cos⎜────── + ─⎟⋅────(φ(x_z))   √3⋅╲╱ -w(x_z) ⋅qₛ(x_z)⋅sin⎜───
#                             ⎝  3      6⎠ dx_z                                     ⎝  3
# ───────────────────────────────────────────────────── + ──────────────────────────────
#                           9                                                   3⋅w(x_z)
#
# _z)   π⎞  d                    _________    ⎛φ(x_z)   π⎞  d               d
# ─── + ─⎟⋅────(w(x_z))   2⋅√3⋅╲╱ -w(x_z) ⋅sin⎜────── + ─⎟⋅────(qₛ(x_z))   ────(C₁(x_z))
#       6⎠ dx_z                               ⎝  3      6⎠ dx_z            dx_z
# ───────────────────── + ────────────────────────────────────────────── - ─────────────
#                                               3                                3

# %% [markdown]
# ### $\frac{d^2}{dx_z^2} \left(  f_2\right)$

# %%
diff(f_2, x_z, x_z)
# Out:
#
#
#
#                                                            2
#          _________            ⎛2⋅φ(x_z) + π⎞ ⎛ d          ⎞            _________
# - 4⋅√3⋅╲╱ -w(x_z) ⋅qₛ(x_z)⋅sin⎜────────────⎟⋅⎜────(φ(x_z))⎟  + 12⋅√3⋅╲╱ -w(x_z) ⋅qₛ(x_
#                               ⎝     6      ⎠ ⎝dx_z        ⎠
#
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
#                                                                                     2
#                                              _________            ⎛2⋅φ(x_z) + π⎞   d
#                                      18⋅√3⋅╲╱ -w(x_z) ⋅qₛ(x_z)⋅sin⎜────────────⎟⋅─────
#                         2                                         ⎝     6      ⎠     2
#       ⎛2⋅φ(x_z) + π⎞   d                                                         dx_z
# z)⋅cos⎜────────────⎟⋅─────(φ(x_z)) + ─────────────────────────────────────────────────
#       ⎝     6      ⎠     2                                     w(x_z)
#                      dx_z
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
# (w(x_z))           _________            ⎛2⋅φ(x_z) + π⎞  d            d
#            12⋅√3⋅╲╱ -w(x_z) ⋅qₛ(x_z)⋅cos⎜────────────⎟⋅────(φ(x_z))⋅────(w(x_z))   9⋅√
#                                         ⎝     6      ⎠ dx_z         dx_z
# ──────── + ───────────────────────────────────────────────────────────────────── - ───
#                                            w(x_z)
#
# ──────────────────────────────────────────────────────────────────────────────────────
#                                                                                      5
#
#
#                                                       2
#     _________            ⎛2⋅φ(x_z) + π⎞ ⎛ d          ⎞
# 3⋅╲╱ -w(x_z) ⋅qₛ(x_z)⋅sin⎜────────────⎟⋅⎜────(w(x_z))⎟
#                          ⎝     6      ⎠ ⎝dx_z        ⎠            _________    ⎛2⋅φ(x_
# ─────────────────────────────────────────────────────── + 36⋅√3⋅╲╱ -w(x_z) ⋅sin⎜──────
#                        2                                                       ⎝     6
#                       w (x_z)
# ──────────────────────────────────────────────────────────────────────────────────────
# 4
#
#
#
#
#            2
# z) + π⎞   d                      _________    ⎛2⋅φ(x_z) + π⎞  d            d
# ──────⎟⋅─────(qₛ(x_z)) + 24⋅√3⋅╲╱ -w(x_z) ⋅cos⎜────────────⎟⋅────(φ(x_z))⋅────(qₛ(x_z)
#       ⎠     2                                 ⎝     6      ⎠ dx_z         dx_z
#         dx_z
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#             _________    ⎛2⋅φ(x_z) + π⎞  d             d
#     36⋅√3⋅╲╱ -w(x_z) ⋅sin⎜────────────⎟⋅────(qₛ(x_z))⋅────(w(x_z))         2
#                          ⎝     6      ⎠ dx_z          dx_z                d
# ) + ────────────────────────────────────────────────────────────── - 18⋅─────(C₁(x_z))
#                                 w(x_z)                                      2
#                                                                         dx_z
# ──────────────────────────────────────────────────────────────────────────────────────

# %%
diff(f_2, x_z, x_z).simplify()
# Out:
#                ⎛                             2
#      _________ ⎜             ⎛φ(x_z)   π⎞   d                          ⎛φ(x_z)   π⎞  d
# √3⋅╲╱ -w(x_z) ⋅⎜3⋅qₛ(x_z)⋅sin⎜────── + ─⎟⋅─────(w(x_z)) + 2⋅qₛ(x_z)⋅cos⎜────── + ─⎟⋅──
#                ⎜             ⎝  3      6⎠     2                        ⎝  3      6⎠ dx
#                ⎝                          dx_z
# ──────────────────────────────────────────────────────────────────────────────────────
#                                                                                  9
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
#
#                                                                       ⎞
#             d                  ⎛φ(x_z)   π⎞  d             d          ⎟
# ──(φ(x_z))⋅────(w(x_z)) + 6⋅sin⎜────── + ─⎟⋅────(qₛ(x_z))⋅────(w(x_z))⎟⋅w(x_z)
# _z         dx_z                ⎝  3      6⎠ dx_z          dx_z        ⎟          √3⋅╲╱
#                                                                       ⎠
# ────────────────────────────────────────────────────────────────────────────── - ─────
#
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
#
#                                                     ⎛
#                                                 2   ⎜         _________            ⎛φ(
# _________            ⎛φ(x_z)   π⎞ ⎛ d          ⎞    ⎜- 4⋅√3⋅╲╱ -w(x_z) ⋅qₛ(x_z)⋅sin⎜──
#  -w(x_z) ⋅qₛ(x_z)⋅sin⎜────── + ─⎟⋅⎜────(w(x_z))⎟    ⎜                              ⎝
#                      ⎝  3      6⎠ ⎝dx_z        ⎠    ⎝
# ───────────────────────────────────────────────── + ──────────────────────────────────
#                      6
# ──────────────────────────────────────────────────────────────────────────────────────
#                                                                    2
#                                                                   w (x_z)
#
#                         2                                                2
# x_z)   π⎞ ⎛ d          ⎞            _________            ⎛φ(x_z)   π⎞   d
# ──── + ─⎟⋅⎜────(φ(x_z))⎟  + 12⋅√3⋅╲╱ -w(x_z) ⋅qₛ(x_z)⋅cos⎜────── + ─⎟⋅─────(φ(x_z)) +
# 3      6⎠ ⎝dx_z        ⎠                                 ⎝  3      6⎠     2
#                                                                       dx_z
# ──────────────────────────────────────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
#
#                                      2
#         _________    ⎛φ(x_z)   π⎞   d                      _________    ⎛φ(x_z)   π⎞
# 36⋅√3⋅╲╱ -w(x_z) ⋅sin⎜────── + ─⎟⋅─────(qₛ(x_z)) + 24⋅√3⋅╲╱ -w(x_z) ⋅cos⎜────── + ─⎟⋅─
#                      ⎝  3      6⎠     2                                 ⎝  3      6⎠ d
#                                   dx_z
# ──────────────────────────────────────────────────────────────────────────────────────
#          54
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
#
#                                   2          ⎞
# d            d                   d           ⎟  2
# ───(φ(x_z))⋅────(qₛ(x_z)) - 18⋅─────(C₁(x_z))⎟⋅w (x_z)
# x_z         dx_z                   2         ⎟
#                                dx_z          ⎠
# ──────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────

# %%
f_3 = Rational(2) * q_s(x_z) * sqrt(- w(x_z) / Rational(3.0)) * cos(phi(x_z)/Rational(3.0) + 4 * pi /Rational(3.0)) - C_1(x_z)/Rational(3.0)
f_3
# Out:
#          _________            ⎛φ(x_z)   π⎞
#   2⋅√3⋅╲╱ -w(x_z) ⋅qₛ(x_z)⋅cos⎜────── + ─⎟
#                               ⎝  3      3⎠   C₁(x_z)
# - ──────────────────────────────────────── - ───────
#                      3                          3

# %% [markdown]
# ### $\frac{d}{dx_z} \left(  f_3\right)$

# %%
diff(f_3, x_z)
# Out:
#        _________            ⎛φ(x_z)   π⎞  d                  _________            ⎛φ(x
# 2⋅√3⋅╲╱ -w(x_z) ⋅qₛ(x_z)⋅sin⎜────── + ─⎟⋅────(φ(x_z))   √3⋅╲╱ -w(x_z) ⋅qₛ(x_z)⋅cos⎜───
#                             ⎝  3      3⎠ dx_z                                     ⎝  3
# ───────────────────────────────────────────────────── - ──────────────────────────────
#                           9                                                   3⋅w(x_z)
#
# _z)   π⎞  d                    _________    ⎛φ(x_z)   π⎞  d               d
# ─── + ─⎟⋅────(w(x_z))   2⋅√3⋅╲╱ -w(x_z) ⋅cos⎜────── + ─⎟⋅────(qₛ(x_z))   ────(C₁(x_z))
#       3⎠ dx_z                               ⎝  3      3⎠ dx_z            dx_z
# ───────────────────── - ────────────────────────────────────────────── - ─────────────
#                                               3                                3

# %% [markdown]
# ### $\frac{d^2}{dx_z^2} \left(  f_3\right)$

# %%
diff(f_3, x_z, x_z)
# Out:
#
#
#
#                                              2
#         _________            ⎛φ(x_z) + π⎞   d                    _________
# 12⋅√3⋅╲╱ -w(x_z) ⋅qₛ(x_z)⋅sin⎜──────────⎟⋅─────(φ(x_z)) + 4⋅√3⋅╲╱ -w(x_z) ⋅qₛ(x_z)⋅cos
#                              ⎝    3     ⎠     2
#                                           dx_z
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                        _________            ⎛φ(x_z) + π⎞  d
#                            2   12⋅√3⋅╲╱ -w(x_z) ⋅qₛ(x_z)⋅sin⎜──────────⎟⋅────(φ(x_z))⋅
# ⎛φ(x_z) + π⎞ ⎛ d          ⎞                                 ⎝    3     ⎠ dx_z
# ⎜──────────⎟⋅⎜────(φ(x_z))⎟  + ───────────────────────────────────────────────────────
# ⎝    3     ⎠ ⎝dx_z        ⎠                                   w(x_z)
#
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
#                                                             2
#                        _________            ⎛φ(x_z) + π⎞   d
#  d             18⋅√3⋅╲╱ -w(x_z) ⋅qₛ(x_z)⋅cos⎜──────────⎟⋅─────(w(x_z))          ______
# ────(w(x_z))                                ⎝    3     ⎠     2           9⋅√3⋅╲╱ -w(x_
# dx_z                                                     dx_z
# ──────────── - ─────────────────────────────────────────────────────── + ─────────────
#                                         w(x_z)
#
# ──────────────────────────────────────────────────────────────────────────────────────
#                                                                             54
#
#
#                                           2
# ___            ⎛φ(x_z) + π⎞ ⎛ d          ⎞
# z) ⋅qₛ(x_z)⋅cos⎜──────────⎟⋅⎜────(w(x_z))⎟
#                ⎝    3     ⎠ ⎝dx_z        ⎠            _________    ⎛φ(x_z) + π⎞  d
# ─────────────────────────────────────────── + 24⋅√3⋅╲╱ -w(x_z) ⋅sin⎜──────────⎟⋅────(φ
#             2                                                      ⎝    3     ⎠ dx_z
#            w (x_z)
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                                                                   ____
#                                                             2             36⋅√3⋅╲╱ -w(
#         d                      _________    ⎛φ(x_z) + π⎞   d
# (x_z))⋅────(qₛ(x_z)) - 36⋅√3⋅╲╱ -w(x_z) ⋅cos⎜──────────⎟⋅─────(qₛ(x_z)) - ────────────
#        dx_z                                 ⎝    3     ⎠     2
#                                                          dx_z
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
# _____    ⎛φ(x_z) + π⎞  d             d
# x_z) ⋅cos⎜──────────⎟⋅────(qₛ(x_z))⋅────(w(x_z))         2
#          ⎝    3     ⎠ dx_z          dx_z                d
# ──────────────────────────────────────────────── - 18⋅─────(C₁(x_z))
#                w(x_z)                                     2
#                                                       dx_z
# ────────────────────────────────────────────────────────────────────

# %% [markdown]
# ### Sub Functionals

# %% [markdown]
# ### $\frac{d}{dx_z} \left(  q_s\right)$

# %%
diff(q(x_z)/abs(q(x_z)), x_z)
# Out:
#   ⎛            d                             d              ⎞                 d
#   ⎜re(q(x_z))⋅────(re(q(x_z))) + im(q(x_z))⋅────(im(q(x_z)))⎟⋅sign(q(x_z))   ────(q(x_
#   ⎝           dx_z                          dx_z            ⎠                dx_z
# - ──────────────────────────────────────────────────────────────────────── + ─────────
#                                          2                                     │q(x_z)
#                                  │q(x_z)│
#
#
# z))
#
# ───
# │

# %% [markdown]
# ### $\frac{d^2}{dx_z^2} \left(  q_s\right)$

# %%
diff(q(x_z)/abs(q(x_z)), x_z, x_z)
# Out:
#
#
#
#
#     ⎛            d                             d              ⎞               d
#   2⋅⎜re(q(x_z))⋅────(re(q(x_z))) + im(q(x_z))⋅────(im(q(x_z)))⎟⋅sign(q(x_z))⋅────(q(x_
#     ⎝           dx_z                          dx_z            ⎠              dx_z
# - ────────────────────────────────────────────────────────────────────────────────────
#                                       q(x_z)⋅│q(x_z)│
#
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
#                                                                    2
#         ⎛            d                             d              ⎞      2
#       2⋅⎜re(q(x_z))⋅────(re(q(x_z))) + im(q(x_z))⋅────(im(q(x_z)))⎟ ⋅sign (q(x_z))
#         ⎝           dx_z                          dx_z            ⎠                  ⎛
#       ──────────────────────────────────────────────────────────────────────────── - ⎜
# z))                                 q(x_z)⋅│q(x_z)│                                  ⎝
#
# ─── + ────────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
#
#                                                                                 ⎛
#                                                                                 ⎜re(q(
#             d                             d              ⎞  d                   ⎝
# re(q(x_z))⋅────(re(q(x_z))) + im(q(x_z))⋅────(im(q(x_z)))⎟⋅────(sign(q(x_z))) + ──────
#            dx_z                          dx_z            ⎠ dx_z
#
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────────────
#                                                              │q(x_z)│
#
#
#        d                             d              ⎞               d
# x_z))⋅────(re(q(x_z))) + im(q(x_z))⋅────(im(q(x_z)))⎟⋅sign(q(x_z))⋅────(q(x_z))   ⎛
#       dx_z                          dx_z            ⎠              dx_z           ⎜
# ─────────────────────────────────────────────────────────────────────────────── - ⎜re(
#                                   q(x_z)                                          ⎜
#                                                                                   ⎝
# ──────────────────────────────────────────────────────────────────────────────────────
#              │q(x_z)│
#
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#            2                              2                                  2
#           d                              d                 ⎛ d              ⎞    ⎛ d
# q(x_z))⋅─────(re(q(x_z))) + im(q(x_z))⋅─────(im(q(x_z))) + ⎜────(re(q(x_z)))⎟  + ⎜────
#             2                              2               ⎝dx_z            ⎠    ⎝dx_z
#         dx_z                           dx_z
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#              2⎞
#             ⎞ ⎟
# (im(q(x_z)))⎟ ⎟⋅sign(q(x_z))
#             ⎠ ⎟                   2
#               ⎠                  d
# ──────────────────────────── + ─────(q(x_z))
#                                    2
#                                dx_z
# ────────────────────────────────────────────

# %% [markdown]
# ### $\frac{d}{dx_z} \left(  \phi \right)$

# %%
phi_func = acos(sqrt(( ((q(x_z)/Rational(2.0))**2)/(w(x_z)/Rational(3.0))**3) ))
phi_func
# Out:
#     ⎛           _________⎞
#     ⎜          ╱  2      ⎟
#     ⎜         ╱  q (x_z) ⎟
#     ⎜3⋅√3⋅   ╱   ─────── ⎟
#     ⎜       ╱     3      ⎟
#     ⎜     ╲╱     w (x_z) ⎟
# acos⎜────────────────────⎟
#     ⎝         2          ⎠

# %%
diff(phi_func, x_z)
# Out:
#             _________ ⎛     2       d                     d          ⎞
#            ╱  2       ⎜  3⋅q (x_z)⋅────(w(x_z))   q(x_z)⋅────(q(x_z))⎟
#           ╱  q (x_z)  ⎜            dx_z                  dx_z        ⎟  3
# -3⋅√3⋅   ╱   ─────── ⋅⎜- ────────────────────── + ───────────────────⎟⋅w (x_z)
#         ╱     3       ⎜           4                      3           ⎟
#       ╲╱     w (x_z)  ⎝        2⋅w (x_z)                w (x_z)      ⎠
# ───────────────────────────────────────────────────────────────────────────────
#                                __________________
#                               ╱       2
#                              ╱    27⋅q (x_z)       2
#                        2⋅   ╱   - ────────── + 1 ⋅q (x_z)
#                            ╱         3
#                          ╲╱       4⋅w (x_z)

# %% [markdown]
# ### $\frac{d^2}{dx_z^2} \left(  \phi \right)$

# %%
diff(phi_func, x_z, x_z)
# Out:
#                      ⎛
#                      ⎜
#                      ⎜                                            2
#                      ⎜    ⎛          d                           ⎞       ⎛          d
#                      ⎜    ⎜3⋅q(x_z)⋅────(w(x_z))                 ⎟       ⎜3⋅q(x_z)⋅───
#            _________ ⎜    ⎜         dx_z              d          ⎟       ⎜         dx_
#           ╱  2       ⎜  4⋅⎜───────────────────── - 2⋅────(q(x_z))⎟    24⋅⎜────────────
#          ╱  q (x_z)  ⎜    ⎝        w(x_z)            dx_z        ⎠       ⎝        w(x_
# 3⋅√3⋅   ╱   ─────── ⋅⎜- ─────────────────────────────────────────── + ────────────────
#        ╱     3       ⎜                     2
#      ╲╱     w (x_z)  ⎜                    q (x_z)
#                      ⎜
#                      ⎜
#                      ⎝
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#                           ⎞                   ⎛          d                           ⎞
# ─(w(x_z))                 ⎟                   ⎜3⋅q(x_z)⋅────(w(x_z))                 ⎟
# z              d          ⎟  d                ⎜         dx_z              d          ⎟
# ───────── - 2⋅────(q(x_z))⎟⋅────(w(x_z))   16⋅⎜───────────────────── - 2⋅────(q(x_z))⎟
# z)            dx_z        ⎠ dx_z              ⎝        w(x_z)            dx_z        ⎠
# ──────────────────────────────────────── - ───────────────────────────────────────────
#      q(x_z)⋅w(x_z)                                                  2
#                                                                    q (x_z)
#
#
#
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#                   ⎛               2
#                   ⎜     2        d                                      2
#                   ⎜  3⋅q (x_z)⋅─────(w(x_z))       2      ⎛ d          ⎞
#                   ⎜                2           12⋅q (x_z)⋅⎜────(w(x_z))⎟
#                   ⎜            dx_z                       ⎝dx_z        ⎠
#   d             8⋅⎜- ─────────────────────── + ────────────────────────── + 2⋅q(x_z)⋅─
# ⋅────(q(x_z))     ⎜           w(x_z)                     2
#  dx_z             ⎝                                     w (x_z)                      d
# ───────────── - ──────────────────────────────────────────────────────────────────────
#                                                                                     2
#                                                                                    q (
#
#
#
# ──────────────────────────────────────────────────────────────────────────────────────
#             __________________
#            ╱       2
#           ╱    27⋅q (x_z)
#    32⋅   ╱   - ────────── + 1
#         ╱         3
#       ╲╱       4⋅w (x_z)
#
#                                                                       ⎞
#                                                                       ⎟
#                           d            d                              ⎟
#   2            12⋅q(x_z)⋅────(q(x_z))⋅────(w(x_z))                   2⎟      ⎛
#  d                       dx_z         dx_z             ⎛ d          ⎞ ⎟      ⎜3⋅q(x_z)
# ────(q(x_z)) - ─────────────────────────────────── + 2⋅⎜────(q(x_z))⎟ ⎟      ⎜
#    2                          w(x_z)                   ⎝dx_z        ⎠ ⎟   27⋅⎜────────
# x_z                                                                   ⎠      ⎝
# ─────────────────────────────────────────────────────────────────────── - ────────────
#                                                                                    ⎛
# x_z)                                                                               ⎜
#                                                                                    ⎜-
#                                                                                    ⎜
#                                                                                    ⎝
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#                                 ⎞
#                                 ⎟
#                                2⎟
#   d                           ⎞ ⎟
# ⋅────(w(x_z))                 ⎟ ⎟
#  dx_z              d          ⎟ ⎟
# ───────────── - 2⋅────(q(x_z))⎟ ⎟
# w(x_z)            dx_z        ⎠ ⎟
# ────────────────────────────────⎟
#     2         ⎞                 ⎟
# 27⋅q (x_z)    ⎟  3              ⎟
# ────────── + 1⎟⋅w (x_z)         ⎟
#    3          ⎟                 ⎟
# 4⋅w (x_z)     ⎠                 ⎠
# ─────────────────────────────────

# %%
diff(phi_func, x_z, x_z).simplify()
# Out:
#            _________
#           ╱  2       ⎛                     2                                     2
#          ╱  q (x_z)  ⎜    3               d                 3      ⎛ d          ⎞
# 3⋅√3⋅   ╱   ─────── ⋅⎜81⋅q (x_z)⋅w(x_z)⋅─────(w(x_z)) - 81⋅q (x_z)⋅⎜────(w(x_z))⎟  - 5
#        ╱     3       ⎜                      2                      ⎝dx_z        ⎠
#      ╲╱     w (x_z)  ⎝                  dx_z
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#                      2                                 2
#    2       2        d                        4        d                        3
# 4⋅q (x_z)⋅w (x_z)⋅─────(q(x_z)) - 12⋅q(x_z)⋅w (x_z)⋅─────(w(x_z)) + 30⋅q(x_z)⋅w (x_z)⋅
#                       2                                 2
#                   dx_z                              dx_z
# ──────────────────────────────────────────────────────────────────────────────────────
#                               __________________________
#                              ╱       2           3
#                             ╱  - 27⋅q (x_z) + 4⋅w (x_z)  ⎛    2           3     ⎞
#                       2⋅   ╱   ──────────────────────── ⋅⎝27⋅q (x_z) - 4⋅w (x_z)⎠⋅q(x_
#                           ╱             3
#                         ╲╱             w (x_z)
#
#
#               2                                   2                2
# ⎛ d          ⎞               2      ⎛ d          ⎞       5        d                 4
# ⎜────(w(x_z))⎟  + 54⋅q(x_z)⋅w (x_z)⋅⎜────(q(x_z))⎟  + 8⋅w (x_z)⋅─────(q(x_z)) - 24⋅w (
# ⎝dx_z        ⎠                      ⎝dx_z        ⎠                  2
#                                                                 dx_z
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
#     2
# z)⋅w (x_z)
#
#
#
#
#                               ⎞
#       d            d          ⎟
# x_z)⋅────(q(x_z))⋅────(w(x_z))⎟
#      dx_z         dx_z        ⎟
#                               ⎠
# ───────────────────────────────

# %% [markdown]
# ### $\frac{d}{dx_z} \left(  q\right)$

# %%
q_func = (Rational(27) * C_3(x_z) - Rational(9) * C_1(x_z) * C_2(x_z) + Rational(2) * (C_2(x_z))**3) / Rational(27)
q_func
# Out:
#                         3
#   C₁(x_z)⋅C₂(x_z)   2⋅C₂ (x_z)
# - ─────────────── + ────────── + C₃(x_z)
#          3              27

# %%
diff(q_func, x_z)
# Out:
#            d                  2       d                       d
#   C₁(x_z)⋅────(C₂(x_z))   2⋅C₂ (x_z)⋅────(C₂(x_z))   C₂(x_z)⋅────(C₁(x_z))
#           dx_z                       dx_z                    dx_z             d
# - ───────────────────── + ──────────────────────── - ───────────────────── + ────(C₃(x
#             3                        9                         3             dx_z
#
#
#
#
# _z))

# %% [markdown]
# ### $\frac{d^2}{dx_z^2} \left(  q \right)$

# %%
diff(q_func, x_z, x_z)
# Out:
#              2                           2                        2
#             d                  2        d                        d
#   C₁(x_z)⋅─────(C₂(x_z))   2⋅C₂ (x_z)⋅─────(C₂(x_z))   C₂(x_z)⋅─────(C₁(x_z))
#               2                           2                        2            4⋅C₂(x
#           dx_z                        dx_z                     dx_z
# - ────────────────────── + ───────────────────────── - ────────────────────── + ──────
#             3                          9                         3
#
#
#
#                    2
#     ⎛ d           ⎞       d             d
# _z)⋅⎜────(C₂(x_z))⎟    2⋅────(C₁(x_z))⋅────(C₂(x_z))      2
#     ⎝dx_z         ⎠      dx_z          dx_z              d
# ──────────────────── - ───────────────────────────── + ─────(C₃(x_z))
#       9                              3                     2
#                                                        dx_z

# %% [markdown]
# ### $\frac{d}{dx_z} \left(  C_1 \right)$

# %%
C_1_func = - ( (R * T / P) + b_mix(x_z))
C_1_func
# Out:
#              R⋅T
# -bₘᵢₓ(x_z) - ───
#               P

# %%
diff(C_1_func, x_z)
# Out:
#   d
# -────(bₘᵢₓ(x_z))
#  dx_z

# %% [markdown]
# ### $\frac{d^2}{dx_z^2} \left(  C_1 \right)$

# %%
diff(C_1_func, x_z, x_z) # NOTE: This is == 0
# Out:
#     2
#    d
# -─────(bₘᵢₓ(x_z))
#      2
#  dx_z

# %% [markdown]
# ### $\frac{d}{dx_z} \left(  C_2 \right)$

# %%
C_2_func = a_mix(x_z) / P
C_2_func
# Out:
# aₘᵢₓ(x_z)
# ─────────
#     P

# %%
diff(C_2_func, x_z)
# Out:
#  d
# ────(aₘᵢₓ(x_z))
# dx_z
# ───────────────
#        P

# %% [markdown]
# ### $\frac{d^2}{dx_z^2} \left(  C_2 \right)$

# %%
diff(C_2_func, x_z, x_z)
# Out:
#    2
#   d
# ─────(aₘᵢₓ(x_z))
#     2
# dx_z
# ────────────────
#        P

# %% [markdown]
# ### $\frac{d}{dx_z} \left(  C_3 \right)$

# %%
C_3_func = - (a_mix(x_z) * b_mix(x_z)) / P
C_3_func
# Out:
# -aₘᵢₓ(x_z)⋅bₘᵢₓ(x_z)
# ─────────────────────
#           P

# %%
diff(C_3_func, x_z)
# Out:
#              d                           d
#   aₘᵢₓ(x_z)⋅────(bₘᵢₓ(x_z))   bₘᵢₓ(x_z)⋅────(aₘᵢₓ(x_z))
#             dx_z                        dx_z
# - ───────────────────────── - ─────────────────────────
#               P                           P

# %% [markdown]
# ### $\frac{d^2}{dx_z^2} \left(  C_3 \right)$

# %%
diff(C_3_func, x_z, x_z)
# Out:
#  ⎛             2                            2
#  ⎜            d                            d                   d               d
# -⎜aₘᵢₓ(x_z)⋅─────(bₘᵢₓ(x_z)) + bₘᵢₓ(x_z)⋅─────(aₘᵢₓ(x_z)) + 2⋅────(aₘᵢₓ(x_z))⋅────(bₘᵢ
#  ⎜              2                            2                dx_z            dx_z
#  ⎝          dx_z                         dx_z
# ──────────────────────────────────────────────────────────────────────────────────────
#                                                P
#
#        ⎞
#        ⎟
# ₓ(x_z))⎟
#        ⎟
#        ⎠
# ─────────
